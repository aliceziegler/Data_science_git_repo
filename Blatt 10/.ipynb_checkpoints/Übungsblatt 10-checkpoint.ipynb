# %% [markdown]
# # Übungsblatt 10 #
#
# ### Alice Ziegler, Daniel Schneider ###

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import scipy.stats
import random
import math

# %% [markdown]
# ### Datensätze einlesen ###

# %%
aggregate = pd.read_csv("data/aggregate.csv")

# %%
plt.scatter(aggregate["x"],aggregate["y"],marker="+")
plt.show()

# %% [markdown]
# Wähle als Clustergröße $7$

# %%
mouse = pd.read_csv("data/mouse.csv")

# %%
plt.scatter(mouse["x"],mouse["y"],marker="+")
plt.show()

# %% [markdown]
# Wähle als Clustergröße $3$

# %%
t48k = pd.read_csv("data/t48k.csv")

# %%
plt.scatter(t48k["x"],t48k["y"],marker="+")
plt.show()

# %% [markdown]
# Wähle als Clustergröße $6$

# %%
jain = pd.read_csv("data/jain.csv")

# %%
plt.scatter(jain["x"],jain["y"],marker="+")
plt.show()

# %% [markdown]
# Wähle als Clustergröße $2$

# %%
spiral = pd.read_csv("data/spiral.csv")

# %%
plt.scatter(spiral["x"],spiral["y"],marker="+")
plt.show()

# %% [markdown]
# Wähle als Clustergröße $3$

# %% [markdown]
# ## Aufgabe 10.1: Expectation Maximization ##

# %%
def probK(x,piK,muK,sigmaK):
    tmp = scipy.stats.multivariate_normal.pdf(x,muK,sigmaK,allow_singular=True)
    return piK * np.nan_to_num(tmp)

# %%
def prob(x,pi,mu,sigma):
    summe = 0
    for k in range(pi.shape[0]):
        summe += probK(x,pi[k],mu[k],sigma[k])
    return summe

# %%
def gammaFunc(x,pi,mu,sigma,k):
    zaehler = probK(x,pi[k],mu[k],sigma[k])
    nenner = prob(x,pi,mu,sigma)
    
    return zaehler / nenner

# %%
def randomMatrix(k,n,a):
    mats = np.empty([k,n,n])
    for i in range(k):
        A = np.matrix([np.random.randn(n) + np.random.randn(1)*a for i in range(n)])
        A = A*np.transpose(A)
        D_half = np.diag(np.diag(A)**(-0.5))
        C = D_half*A*D_half
        mats[i] = C
    return mats

# %%
def EM(x, k):
    N,d = x.shape
    
    mu = np.random.uniform(0,1,(k,d))
    sigma = randomMatrix(k,d,2) #np.random.uniform(0,1,(k,d,d))
    pi = np.random.uniform(0,1,k)
    
    # E-Schritt
    gamma = np.empty([N,k])
    for j in range(k):
        gamma[:,j] = gammaFunc(x.values, pi, mu, sigma, j)
    
    #return(gamma)
    gammaPrev = np.zeros_like(gamma)
    
    counter = 0
    while(not(np.isclose(gamma,gammaPrev).all())):
        gammaPrev = gamma.copy()
        
        # M-Schritt
        Ns = [None] * k
        for j in range(k):
            #N_k
            Ns[j] = np.nansum(gamma[:,j], axis=0)
            
            #mu_k
            summe = 0
            for i in range(N):
                summe += gamma[i,j] * x.values[i]
            mu[j] = 1/Ns[j] * summe
                    
            #sigma_k
            summe = 0
            for i in range(N):
                summe += gamma[i,j] * np.dot(
                    np.transpose((x.values[i] - mu[j])[np.newaxis]), (x.values[i] - mu[j])[np.newaxis]
                )
            sigma[j] = 1/Ns[j] * summe
            
            #pi_k
            pi[j] = Ns[j]/N

        mu = np.nan_to_num(mu)
        sigma = np.nan_to_num(sigma)
        pi = np.nan_to_num(pi)
        
        
        # E-Schritt
        for j in range(k):
            gamma[:,j] = gammaFunc(x, pi, mu, sigma, j)
        
        counter += 1
        
        if(counter == -1):
            #print(gamma)
            print(Ns)
            print(mu)
            print(sigma)
            print(pi)
        #elif(counter > 6):
        #    break
        #print(counter)
    return gamma

# %%
probabilitiesAggregate0 = EM(aggregate, 7)

# %%
cmap = plt.get_cmap('jet', probabilitiesAggregate0.shape[1])
colorIDsAggregate0 = [None] * probabilitiesAggregate0.shape[0]

for i in range(probabilitiesAggregate0.shape[0]):
    colors = np.zeros([3])
    for j in range(probabilitiesAggregate0.shape[1]):
        colors += np.asarray(cmap(j)[0:3]) * probabilitiesAggregate0[i,j]
    
    colorIDsAggregate0[i] = np.round(colors,decimals=3)
#print(colorIDsAggregate0)     
plt.scatter(aggregate["x"],aggregate["y"], c=colorIDsAggregate0, cmap=cmap, marker="+")

plt.show()

# %%
probabilitiesMouse0 = EM(mouse, 3)

# %%
cmap = plt.get_cmap('jet', probabilitiesMouse0.shape[1])
colorIDsMouse0 = [None] * probabilitiesMouse0.shape[0]

for i in range(probabilitiesMouse0.shape[0]):
    colors = np.zeros([3])
    for j in range(probabilitiesMouse0.shape[1]):
        colors += np.asarray(cmap(j)[0:3]) * probabilitiesMouse0[i,j]
    
    colorIDsMouse0[i] = np.round(colors,decimals=3)
#print(colorIDsAggregate0)     
plt.scatter(mouse["x"],mouse["y"], c=colorIDsMouse0, cmap=cmap, marker="+")

plt.show()

# %% [markdown]
# ## Aufgabe 10.2: Non-Convex Clustering ##

# %% [markdown]
# #### Funktionen zur Berechnung einer Distanzmatrix ####

# %%
def dist(x,y,dtypes,columns,normalize):
    
    dist = 0
    for f in range(len(columns)):
        
        if dtypes[f].name == "category":
            if x[attribs[f]].cat.ordered:
                dist += distOrdinal(x[columns[f]],y[columns[f]])
            else:
                dist += distNominal(x[columns[f]],y[columns[f]])
        else:
            dist += distNumeric(x[columns[f]],y[columns[f]],normalize[f])
    
    return dist

# %%
def distOrdinal(x,y):
    rankCount = len(x.cat.categories)
    
    rankX = (int(x.cat.codes))/(rankCount - 1)
    rankY = (int(y.cat.codes))/(rankCount - 1)    
    dist = abs(rankX - rankY)
    
    return dist

# %%
def distNominal(x,y):
    if x == y:
        dist = 0
    else:
        dist = 1
    
    return dist

# %%
def distNumeric(x,y,normalize):
    dist = abs(float(x) - float(y))/(normalize)
    
    return dist

# %%
def metadata(data):
    types = data.dtypes
    columns = data.columns
    
    mins = data.min(axis=0)
    maxs = data.max(axis=0)
    normalize = (maxs - mins)
    
    return types,columns,normalize

# %%
def distMatrix(data1,data2,excludeAttributes):
    data1 = data1.drop(excludeAttributes,axis=1)
    data2 = data2.drop(excludeAttributes,axis=1)
    
    if data1.equals(data2):
        symetrical = True
    else:
        symetrical = False
    
    types,columns,normalize = metadata(data1)
        
    array = np.empty([data1.shape[0], data2.shape[0]])
        
    for i in range(data1.shape[0]):        
        for j in range(data2.shape[0]):
            if (symetrical and j < i):
                array[i,j] = array[j,i]
            else:
                array[i,j] = dist(data1.iloc[[i]],data2.iloc[[j]],types,columns,normalize)
        
    return array

# %% [markdown]
# ### $k$-means ###

# %%
def kMeans(data,k):
    N = data.shape[0]
    
    ms = data.sample(n=k).reset_index(drop=True)
    msPrev = pd.DataFrame(np.zeros_like(ms))
    
    while(not((np.isclose(ms.values,msPrev.values)).all())):
        msPrev = ms.copy()
        bs = np.zeros([N,k])
        
        #print(ms)
        
        #Berechnung der bij-Matrix
        for i in range(N):
            minDist = float('inf')

            for j in range(k):
                dist = np.linalg.norm(data.loc[i] - ms.loc[j])

                if(dist < minDist):
                    minDist = dist
                    minDistClass = j

            bs[i,minDistClass] = 1

        #Anpassung der mj
        for j in range(k):
            zaehler = np.sum(np.c_[bs[:,j],bs[:,j]] * data)
            nenner = np.sum(bs[:,j])

            ms.loc[j] = zaehler/nenner
        #print(ms)
        #print(ms.equals(msPrev))
    classIDs = np.dot(bs, range(bs.shape[1]))
    return (ms,classIDs)

# %% [markdown]
# #### `aggregate`-Datensatz ####

# %%
msAggregate,colorIDsAggregate = kMeans(aggregate,5)

# %%
cmap = plt.get_cmap('jet', colorIDsAggregate.max()+1)

plt.scatter(aggregate["x"],aggregate["y"],c=colorIDsAggregate, cmap=cmap, marker="+")
plt.scatter(msAggregate["x"],msAggregate["y"],c="white")

plt.show()

# %% [markdown]
# #### `mouse`-Datensatz ####

# %%
msMouse,colorIDsMouse = kMeans(mouse,3)

# %%
cmap = plt.get_cmap('jet', colorIDsMouse.max()+1)

plt.scatter(mouse["x"],mouse["y"],c=colorIDsMouse, cmap=cmap, marker="+")
plt.scatter(msMouse["x"],msMouse["y"],c="white")

plt.show()

# %% [markdown]
# ### b) fuzzy-$c$-Means

# %%
def fuzzyCMeans(data,k, p=2):
    N = data.shape[0]
    
    ms = data.sample(n=k).reset_index(drop=True)
    msPrev = pd.DataFrame(np.zeros_like(ms))
    
    while(not((np.isclose(ms.values,msPrev.values)).all())):
        msPrev = ms.copy()
        us = np.zeros([N,k])
        
        #Berechnung der uij-Matrix
        for i in range(N):
            minDist = float('inf')

            for j in range(k):
                distMj = np.square(np.linalg.norm(ms.loc[j] - data.loc[i]))
                
                summe = 0
                for l in range(k):
                    distMl = np.square(np.linalg.norm(ms.loc[l] - data.loc[i]))
                    
                    summe += np.power(distMj/distMl,(p/(p-1)))
                    #print(summe)
                
                us[i,j] = 1/summe
        
        #print(us)
        
        #Anpassung der mj
        for j in range(k):
            usP = np.power(us[:,j],p)
            
            zaehler = np.nansum(np.c_[usP,usP] * data, axis=0)
            nenner = np.nansum(usP, axis=0)

            ms.loc[j] = zaehler/nenner
        #print(ms)
    return (ms,us)

# %% [markdown]
# #### `aggregate`-Datensatz ####

# %%
msAggregate2,usAggregate2 = fuzzyCMeans(aggregate,5)

# %%
cmap = plt.get_cmap('jet', usAggregate2.shape[1])
colorIDsAggregate2 = [None] * usAggregate2.shape[0]

for i in range(usAggregate2.shape[0]):
    colors = np.zeros([3])
    for j in range(usAggregate2.shape[1]):
        colors += np.asarray(cmap(j)[0:3]) * usAggregate2[i,j]

    colorIDsAggregate2[i] = colors
        
plt.scatter(aggregate["x"],aggregate["y"], c=colorIDsAggregate2, cmap=cmap, marker="+")

plt.scatter(msAggregate2["x"],msAggregate2["y"],c="white")

plt.show()

# %% [markdown]
# #### `mouse`-Datensatz ####

# %%
msMouse2,usMouse2 = fuzzyCMeans(mouse,3)

# %%
cmap = plt.get_cmap('jet', usMouse2.shape[1])
colorIDsMouse2 = [None] * usMouse2.shape[0]

for i in range(usMouse2.shape[0]):
    colors = np.zeros([3])
    for j in range(usMouse2.shape[1]):
        colors += np.asarray(cmap(j)[0:3]) * usMouse2[i,j]

    colorIDsMouse2[i] = colors
        
plt.scatter(mouse["x"],mouse["y"], c=colorIDsMouse2, cmap=cmap, marker="+")

plt.scatter(msMouse2["x"],msMouse2["y"],c="white")

plt.show()

# %% [markdown]
# ### c) Agglomeratives Clustering ###

# %% [markdown]
# #### Clustering-Algorithmus ####

# %%
def agglomerativeClustering(data, k, linkage, dist=None):
    
    if distMatrix == None:
        dist = distMatrix(data,data,[])
    
    N = dist.shape[0]
    
    for i in range(N):
        dist[i,i] = None
        
    groups = [None] * N
    for i in range(N):
        groups[i] = data.loc[[i]]
    
    #print(groups)
    for i in range(N-k): #(10):#
        N = dist.shape[0]
        
        m = np.nanargmin(dist)
        index0 = m//N
        index1 = m%N
        
        groups[index0] = groups[index0].append(groups[index1])
        del(groups[index1])
        
        for i in range(N):
            #print("Old:"+str(dist[index0,i] - dist[index1,i]))
            if linkage == "single":
                dist[index0,i] = min(dist[index0,i],dist[index1,i])
            elif linkage == "complete":
                dist[index0,i] = max(dist[index0,i],dist[index1,i])
            
            dist[i,index0] = dist[index0,i]
            #print("New:"+str(dist[index0,i]))
        
        
        dist = np.delete(dist,index1,axis=0)
        dist = np.delete(dist,index1,axis=1)
        
    return groups

# %% [markdown]
# #### Durchführung des Clusterings für den `aggregate`-Datensatz ####

# %%
distMatrixAggregate = distMatrix(aggregate,aggregate,[])

# %% [markdown]
# ##### *Single-Link* #####

# %%
aggregateGroupsSingle = agglomerativeClustering(aggregate, 5, "single", distMatrixAggregate)

# %%
cmap = plt.get_cmap('jet', len(aggregateGroupsSingle))

for i in range(len(aggregateGroupsSingle)):
    plt.scatter(aggregateGroupsSingle[i]["x"],aggregateGroupsSingle[i]["y"],c=cmap(i), cmap=cmap, marker="+")

#plt.scatter(msAggregate["x"],msAggregate["y"],c="white")

plt.show()

# %% [markdown]
# ##### *Complete-Link* #####

# %%
aggregateGroupsComplete = agglomerativeClustering(aggregate, 3, "complete", distMatrixAggregate)

# %%
cmap = plt.get_cmap('jet', len(aggregateGroupsComplete))

for i in range(len(aggregateGroupsComplete)):
    plt.scatter(aggregateGroupsComplete[i]["x"],aggregateGroupsComplete[i]["y"],c=cmap(i), cmap=cmap, marker="+")

#plt.scatter(msAggregate["x"],msAggregate["y"],c="white")

plt.show()

# %% [markdown]
# #### Durchführung des Clusterings für den `mouse`-Datensatz ####

# %%
distMatrixMouse = distMatrix(mouse,mouse,[])

# %% [markdown]
# ##### *Single-Link* #####

# %%
mouseGroupsSingle = agglomerativeClustering(mouse, 3, "single", distMatrixMouse)

# %%
cmap = plt.get_cmap('jet', len(mouseGroupsSingle))

for i in range(len(mouseGroupsSingle)):
    plt.scatter(mouseGroupsSingle[i]["x"],mouseGroupsSingle[i]["y"],c=cmap(i), cmap=cmap, marker="+")

#plt.scatter(msAggregate["x"],msAggregate["y"],c="white")

plt.show()

# %% [markdown]
# ##### *Complete-Link* #####

# %%
mouseGroupsComplete = agglomerativeClustering(mouse, 3, "complete", distMatrixMouse)

# %%
cmap = plt.get_cmap('jet', len(mouseGroupsComplete))

for i in range(len(mouseGroupsComplete)):
    plt.scatter(mouseGroupsComplete[i]["x"],mouseGroupsComplete[i]["y"],c=cmap(i), cmap=cmap, marker="+")

#plt.scatter(msAggregate["x"],msAggregate["y"],c="white")

plt.show()

# %% [markdown]
# ### Vergleich der Klassifizierer ###

# %% [markdown]
# #### `aggregate`-Datensatz ####

# %%
plt.close('all')
mpl.rcParams['figure.figsize'] = (12,8)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharey='all', sharex='all')

#k-means
cmap = plt.get_cmap('jet', colorIDsAggregate.max()+1)

ax1.scatter(aggregate["x"],aggregate["y"],c=colorIDsAggregate, cmap=cmap, marker="+")
ax1.scatter(msAggregate["x"],msAggregate["y"],c="white")
ax1.set_title('k-means')

#fuzzy-c-means
cmap = plt.get_cmap('jet', usAggregate2.shape[1])
colorIDsAggregate2 = [None] * usAggregate2.shape[0]

for i in range(usAggregate2.shape[0]):
    colors = np.zeros([3])
    for j in range(usAggregate2.shape[1]):
        colors += np.asarray(cmap(j)[0:3]) * usAggregate2[i,j]

    colorIDsAggregate2[i] = colors
        
ax2.scatter(aggregate["x"],aggregate["y"], c=colorIDsAggregate2, cmap=cmap, marker="+")
ax2.scatter(msAggregate2["x"],msAggregate2["y"],c="white")
ax2.set_title('fuzzy-c-means')

#single-link
cmap = plt.get_cmap('jet', len(aggregateGroupsSingle))

for i in range(len(aggregateGroupsSingle)):
    ax3.scatter(aggregateGroupsSingle[i]["x"],aggregateGroupsSingle[i]["y"],c=cmap(i), cmap=cmap, marker="+")
ax3.set_title('single-link')

#complete-link
cmap = plt.get_cmap('jet', len(aggregateGroupsComplete))

for i in range(len(aggregateGroupsComplete)):
    ax4.scatter(aggregateGroupsComplete[i]["x"],aggregateGroupsComplete[i]["y"],c=cmap(i), cmap=cmap, marker="+")
ax4.set_title('complete-link')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

plt.show()
mpl.rcParams['figure.figsize'] = (6,4)

# %% [markdown]
# Die single-Link-Klassifikation liefert das natürlichste Ergebnis. Die optisch zusammenhängenden Bereiche gehören jeweils zu einem Cluster und die nicht zusammenhängenden sind in unterschiedlichen Clustern.
# Die Ergenisse der anderen drei Ansätze sind zueinander recht ähnlich und alle keine schlechten Clustereinteilungen, auch wenn sie nicht vollständig der optischen Unterteilung folgen.

# %% [markdown]
# #### `mouse`-Datensatz ####

# %%
plt.close('all')
mpl.rcParams['figure.figsize'] = (12,8)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharey='all', sharex='all')

#k-means
cmap = plt.get_cmap('jet', colorIDsMouse.max()+1)

ax1.scatter(mouse["x"],mouse["y"],c=colorIDsMouse, cmap=cmap, marker="+")
ax1.scatter(msMouse["x"],msMouse["y"],c="white")
ax1.set_title('k-means')

#fuzzy-c-means
cmap = plt.get_cmap('jet', usMouse2.shape[1])
colorIDsMouse2 = [None] * usMouse2.shape[0]

for i in range(usMouse2.shape[0]):
    colors = np.zeros([3])
    for j in range(usMouse2.shape[1]):
        colors += np.asarray(cmap(j)[0:3]) * usMouse2[i,j]

    colorIDsMouse2[i] = colors
        
ax2.scatter(mouse["x"],mouse["y"], c=colorIDsMouse2, cmap=cmap, marker="+")
ax2.scatter(msMouse2["x"],msMouse2["y"],c="white")
ax2.set_title('fuzzy-c-means')

#single-link
cmap = plt.get_cmap('jet', len(mouseGroupsSingle))

for i in range(len(mouseGroupsSingle)):
    ax3.scatter(mouseGroupsSingle[i]["x"],mouseGroupsSingle[i]["y"],c=cmap(i), cmap=cmap, marker="+")
ax3.set_title('single-link')

#complete-link
cmap = plt.get_cmap('jet', len(mouseGroupsComplete))

for i in range(len(mouseGroupsComplete)):
    ax4.scatter(mouseGroupsComplete[i]["x"],mouseGroupsComplete[i]["y"],c=cmap(i), cmap=cmap, marker="+")
ax4.set_title('complete-link')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

plt.show()
mpl.rcParams['figure.figsize'] = (6,4)

# %% [markdown]
# Hier ist eine optische Trennung nicht so eindeutig, da es einige Ausreißerpunkte gibt, die außerhalb der optisch sichtbaren Gruppen liegen. Das sorgt auch dafür, dass der single-link-Ansatz hier kein brauchbares Ergebnis liefert, da zwei von drei Clustern nur aus jeweils einem dieser Ausreißerpunkte bestehen.
# Meiner Meinung nach liefert fuzzy-c-means hier die beste Einteilung, da die Übergänge zwischen den Clustern, die hier ja nicht so klar ersichtlich sind, fließend verlaufen und die Clustereinteilung so noch am ehesten der optischen Unterteilung folgt.

# %% [markdown]
# ## Aufgabe 3
# ### a) Probleme beim Clustering mit stark unterschiedlichen Varianzen
# Zur Vereinfachung kann man einen zweidimensionalen Datensatz mit hoher Varianz entlang der x- und sehr kleiner Varianz entlang der y-Achse betrachten. Mehrere Klassen liegen dabei in langgestreckten Punktwolken relativ eng übereinander. Zum Beispiel Gramm Körpermasse auf der x-Achse und Schuhgröße auf der y-Achse - die Klassen könnten Männer und Frauen sein.  K-Means-Clustering geht von einer isotropen Verteilung aus und neigt deshalb eher zu runden (zweidimensional) als zu länglichen Clustern. Wenn die Varianzen stark unterschiedlich sind bedeutet das, dass mehr Gewichtung auf die Variable mit der kleineren Varianz gelegt wird. Das hat zur Folge, dass Cluster eher entlang von Variablen mit großer Varianz getrennt werden.
#
# ### b) Ansätze zum Umgehen der Probleme
#
# Um das Problem der unterschiedlichen Varianzen zu umgehen, sollten die Variablen vor einem Clustervergahren standardisiert werden.
# Wenn mehrere Variablen korreliert sind, bedeutet das, dass bestimmte Informationen mehrfach in die Clusterung eingehen. Abhilfe dagegen kann ein anderes Distanzmaß schaffen. Der Mahalanobis-Abstand ist zum Beispiel eine verallgemeinerung des Euklidischen-Abstands, welcher die Korrelation der Variablen berücksichtigt.
